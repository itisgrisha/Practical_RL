# %% [markdown]
# # Crossentropy method
#
# This notebook will teach you to solve reinforcement learning problems with crossentropy method. We'll follow-up by scaling everything up and using neural network policy.

# %%
# In google collab, uncomment this:
# !wget https://bit.ly/2FMJP5K -O setup.py && bash setup.py

# XVFB will be launched if you run on a server
import os
if type(os.environ.get("DISPLAY")) is not str or len(os.environ.get("DISPLAY")) == 0:
    # !bash ../xvfb start
    # %env DISPLAY = : 1
# Out:
# Starting virtual X frame buffer: Xvfb.
# env: DISPLAY=: 1

# %%
import gym
import numpy as np
import pandas as pd

env = gym.make("Taxi-v2")
env.reset()
env.render()
# Out:
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+

# %%
n_states = env.observation_space.n
n_actions = env.action_space.n

print("n_states=%i, n_actions=%i" % (n_states, n_actions))
# Out:
# n_states=500, n_actions=6

# %% [markdown]
# # Create stochastic policy
#
# This time our policy should be a probability distribution.
#
# ```policy[s,a] = P(take action a | in state s)```
#
# Since we still use integer state and action representations, you can use a 2-dimensional array to represent the policy.
#
# Please initialize policy __uniformly__, that is, probabililities of all actions should be equal.

# %%
policy = np.ones((n_states, n_actions)) / n_actions

# %%
assert type(policy) in (np.ndarray, np.matrix)
assert np.allclose(policy, 1./n_actions)
assert np.allclose(np.sum(policy, axis=1), 1)

# %% [markdown]
# # Play the game
#
# Just like before, but we also record all states and actions we took.

# %%
def generate_session(policy, t_max=10**4):
    """
    Play game until end or for t_max ticks.
    :param policy: an array of shape [n_states,n_actions] with action probabilities
    :returns: list of states, list of actions and sum of rewards
    """
    states, actions = [], []
    total_reward = 0.

    s = env.reset()

    for t in range(t_max):
        a = np.random.choice(policy.shape[1], p=policy[s])

        new_s, r, done, info = env.step(a)

        # Record state, action and add up reward to states,actions and total_reward accordingly.
        states.append(s)
        actions.append(a)
        total_reward += r

        s = new_s
        if done:
            break
    return states, actions, total_reward

# %%
s, a, r = generate_session(policy)
assert type(s) == type(a) == list
assert len(s) == len(a)
assert type(r) in [float, np.float]

# %%
# let's see the initial reward distribution
import matplotlib.pyplot as plt
# %matplotlib inline

sample_rewards = [generate_session(policy, t_max=1000)[-1] for _ in range(200)]

plt.hist(sample_rewards, bins=20)
plt.vlines([np.percentile(sample_rewards, 50)], [0], [
           100], label="50'th percentile", color='green')
plt.vlines([np.percentile(sample_rewards, 90)], [0], [
           100], label="90'th percentile", color='red')
plt.legend()

# %% [markdown]
# ### Crossentropy method steps (2pts)

# %%
def select_elites(states_batch, actions_batch, rewards_batch, percentile=50):
    """
    Select states and actions from games that have rewards >= percentile
    :param states_batch: list of lists of states, states_batch[session_i][t]
    :param actions_batch: list of lists of actions, actions_batch[session_i][t]
    :param rewards_batch: list of rewards, rewards_batch[session_i][t]

    :returns: elite_states,elite_actions, both 1D lists of states and respective actions from elite sessions

    Please return elite states and actions in their original order 
    [i.e. sorted by session number and timestep within session]

    If you're confused, see examples below. Please don't assume that states are integers (they'll get different later).
    """

    reward_threshold = np.percentile(rewards_batch, percentile)
    elite_idx = np.where(np.array(rewards_batch) >= reward_threshold)[0]
    elite_states = [state for idx in elite_idx for state in states_batch[idx]]
    elite_actions = [action for idx in elite_idx for action in actions_batch[idx]]
    return elite_states, elite_actions

# %%
states_batch = [
    [1, 2, 3],  # game1
    [4, 2, 0, 2],  # game2
    [3, 1]  # game3
]

actions_batch = [
    [0, 2, 4],  # game1
    [3, 2, 0, 1],  # game2
    [3, 3]  # game3
]
rewards_batch = [
    3,  # game1
    4,  # game2
    5,  # game3
]

test_result_0 = select_elites(
    states_batch, actions_batch, rewards_batch, percentile=0)
test_result_40 = select_elites(
    states_batch, actions_batch, rewards_batch, percentile=30)
test_result_90 = select_elites(
    states_batch, actions_batch, rewards_batch, percentile=90)
test_result_100 = select_elites(
    states_batch, actions_batch, rewards_batch, percentile=100)

assert np.all(test_result_0[0] == [1, 2, 3, 4, 2, 0, 2, 3, 1])  \
    and np.all(test_result_0[1] == [0, 2, 4, 3, 2, 0, 1, 3, 3]),\
    "For percentile 0 you should return all states and actions in chronological order"
assert np.all(test_result_40[0] == [4, 2, 0, 2, 3, 1]) and \
    np.all(test_result_40[1] == [3, 2, 0, 1, 3, 3]),\
    "For percentile 30 you should only select states/actions from two first"
assert np.all(test_result_90[0] == [3, 1]) and \
    np.all(test_result_90[1] == [3, 3]),\
    "For percentile 90 you should only select states/actions from one game"
assert np.all(test_result_100[0] == [3, 1]) and\
    np.all(test_result_100[1] == [3, 3]),\
    "Please make sure you use >=, not >. Also double-check how you compute percentile."
print("Ok!")
# Out:
# Ok!

# %%
def update_policy(elite_states, elite_actions):
    """
    Given old policy and a list of elite states/actions from select_elites,
    return new updated policy where each action probability is proportional to

    policy[s_i,a_i] ~ #[occurences of si and ai in elite states/actions]

    Don't forget to normalize policy to get valid probabilities and handle 0/0 case.
    In case you never visited a state, set probabilities for all actions to 1./n_actions

    :param elite_states: 1D list of states from elite sessions
    :param elite_actions: 1D list of actions from elite sessions

    """

    new_policy = np.zeros([n_states, n_actions])
    elite_pairs = np.vstack((elite_states, elite_actions))
    
    uniques, counts = np.unique(elite_pairs, return_counts=True, axis=-1)
    
    new_policy[tuple(uniques)] = counts
    denominator = np.sum(new_policy, axis=-1)
    
    seen_pairs = denominator > 0
    new_policy[~seen_pairs] = np.ones(n_actions) / n_actions
    new_policy[seen_pairs] /= denominator[seen_pairs].reshape(sum(seen_pairs), -1)

    return new_policy

# %%
elite_states, elite_actions = ([1, 2, 3, 4, 2, 0, 2, 3, 1], [
                               0, 2, 4, 3, 2, 0, 1, 3, 3])


new_policy = update_policy(elite_states, elite_actions)

assert np.isfinite(new_policy).all(
), "Your new policy contains NaNs or +-inf. Make sure you don't divide by zero."
assert np.all(
    new_policy >= 0), "Your new policy can't have negative action probabilities"
assert np.allclose(new_policy.sum(
    axis=-1), 1), "Your new policy should be a valid probability distribution over actions"
reference_answer = np.array([
    [1.,  0.,  0.,  0.,  0.],
    [0.5,  0.,  0.,  0.5,  0.],
    [0.,  0.33333333,  0.66666667,  0.,  0.],
    [0.,  0.,  0.,  0.5,  0.5]])
assert np.allclose(new_policy[:4, :5], reference_answer)
print("Ok!")
# Out:
# Ok!

# %% [markdown]
# # Training loop
# Generate sessions, select N best and fit to those.

# %%
from IPython.display import clear_output


def show_progress(rewards_batch, log, reward_range=[-990, +10], ax=None, percentile=50):
    """
    A convenience function that displays training progress. 
    No cool math here, just charts.
    """

    mean_reward = np.mean(rewards_batch)
    threshold = np.percentile(rewards_batch, percentile)
    log.append([mean_reward, threshold])

    clear_output(True)
    print("mean reward = %.3f, threshold=%.3f" % (mean_reward, threshold))
    plt.figure(figsize=[8, 4])
    plt.subplot(1, 2, 1)
    plt.plot(list(zip(*log))[0], label='Mean rewards')
    plt.plot(list(zip(*log))[1], label='Reward thresholds')
    plt.legend()
    plt.grid()

    plt.subplot(1, 2, 2)
    plt.hist(rewards_batch, range=reward_range)
    plt.vlines([np.percentile(rewards_batch, percentile)],
               [0], [100], label="percentile", color='red')
    plt.legend()
    plt.grid()

    plt.show()

# %%
# reset policy just in case
policy = np.ones([n_states, n_actions])/n_actions

# %%
n_sessions = 2*250  # sample this many sessions
percentile = 10  # take this percent of session with highest rewards
learning_rate = 0.6  # add this thing to all counts for stability

log = []

for i in range(100):
    
    if i < 30:
        percentile = 60
    elif i < 60:
        percentile = 10
    else:
        percentile = 3

    sessions = [generate_session(policy, t_max=10000) for _ in range(n_sessions)]

    states_batch, actions_batch, rewards_batch = zip(*sessions)

    elite_states, elite_actions = select_elites(states_batch, actions_batch, rewards_batch, percentile)

    new_policy = update_policy(elite_states, elite_actions)

    policy = learning_rate * new_policy + (1 - learning_rate) * policy 

    # display results on chart
    show_progress(rewards_batch, log)
# Out:
# mean reward = 7.788, threshold=8.000

# %% [markdown]
# # Digging deeper: approximate crossentropy with neural nets
#
# ![img](https://casd35.wikispaces.com/file/view/digging_deeper_final.jpg/359658499/503x260/digging_deeper_final.jpg)
#
# In this section we will train a neural network policy for continuous state space game

# %%
# if you see "<classname> has no attribute .env", remove .env or update gym
env = gym.make("CartPole-v0").env

env.reset()
n_actions = env.action_space.n

plt.imshow(env.render("rgb_array"))

# %%
# create agent
from sklearn.neural_network import MLPClassifier
agent = MLPClassifier(hidden_layer_sizes=(20, 20),
                      activation='tanh',
                      warm_start=True,  # keep progress between .fit(...) calls
                      max_iter=1  # make only 1 iteration on each .fit(...)
                      )
# initialize agent to the dimension of state an amount of actions
agent.fit([env.reset()]*n_actions, range(n_actions))
# Out:
# /usr/local/lib/python3.5/dist-packages/sklearn/neural_network/multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# MLPClassifier(activation='tanh', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(20, 20), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=1, momentum=0.9,
#        n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#        random_state=None, shuffle=True, solver='adam', tol=0.0001,
#        validation_fraction=0.1, verbose=False, warm_start=True)

# %%
def generate_session_mlp(t_max=1000):

    states, actions = [], []
    total_reward = 0

    s = env.reset()

    for t in range(t_max):

        # predict array of action probabilities
        probs = agent.predict_proba([s])[0]

        a = np.random.choice(n_actions, p=probs)

        new_s, r, done, info = env.step(a)

        # record sessions like you did before
        states.append(s)
        actions.append(a)
        total_reward += r

        s = new_s
        if done:
            break
    return states, actions, total_reward

# %%
n_sessions = 100
percentile = 70
log = []

for i in range(100):
    # generate new sessions
    sessions = [generate_session_mlp() for _ in range(n_sessions)]

    states_batch, actions_batch, rewards_batch = map(np.array, zip(*sessions))

    elite_states, elite_actions, threshold = select_elites(states_batch, actions_batch, rewards_batch, percentile)
    
    agent.fit(elite_states, elite_actions)

    show_progress(rewards_batch, log, reward_range=[0, np.max(rewards_batch)])

    if np.mean(rewards_batch) > 190:
        print("You Win! You may stop training now via KeyboardInterrupt.")
# Out:
# mean reward = 223.990, threshold=204.500
# You Win! You may stop training now via KeyboardInterrupt.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-220-b9bdca6db479> in <module>
#       5 for i in range(100):
#       6     # generate new sessions
# ----> 7     sessions = [generate_session_mlp() for _ in range(n_sessions)]
#       8
#       9     states_batch, actions_batch, rewards_batch = map(np.array, zip(*sessions))
#
# <ipython-input-220-b9bdca6db479> in <listcomp>(.0)
#       5 for i in range(100):
#       6     # generate new sessions
# ----> 7     sessions = [generate_session_mlp() for _ in range(n_sessions)]
#       8
#       9     states_batch, actions_batch, rewards_batch = map(np.array, zip(*sessions))
#
# <ipython-input-219-597f51523f80> in generate_session_mlp(t_max)
#       9
#      10         # predict array of action probabilities
# ...

# %% [markdown]
# # Results

# %%
# record sessions
import gym.wrappers
env = gym.wrappers.Monitor(gym.make("CartPole-v0"),
                           directory="videos", force=True)
sessions = [generate_session_mlp() for _ in range(100)]
env.close()

# %%
# show video
from IPython.display import HTML
import os

video_names = list(
    filter(lambda s: s.endswith(".mp4"), os.listdir("./videos/")))

HTML("""
<video width="640" height="480" controls>
  <source src="{}" type="video/mp4">
</video>
""".format("./videos/"+video_names[-1]))  # this may or may not be _last_ video. Try other indices
# Out:
# <video width="640" height="480" controls>
#   <source src="./videos/openaigym.video.42.10651.video000027.mp4" type="video/mp4">
# </video>

# %% [markdown]
# # Homework part I
#
# ### Tabular crossentropy method
#
# You may have noticed that the taxi problem quickly converges from -100 to a near-optimal score and then descends back into -50/-100. This is in part because the environment has some innate randomness. Namely, the starting points of passenger/driver change from episode to episode.
#
# ### Tasks
# - __1.1__ (1 pts) Find out how the algorithm performance changes if you change different percentile and different n_samples.
# - __1.2__ (2 pts) Tune the algorithm to end up with positive average score.
#
# It's okay to modify the existing code.

# %% [markdown]
# ## 1.1

# %%
from multiprocessing import Pool
from itertools import chain
from time import time
from tqdm import tqdm_notebook as tqdm

def show_progress(rewards_batch, log, reward_range=[-990, +10], ax=None):
    """
    A convenience function that displays training progress. 
    No cool math here, just charts.
    """

    clear_output(True)
    plt.figure(figsize=[8, 4])
    plt.subplot(1, 2, 1)
    plt.plot(list(zip(*log))[0], label='Mean rewards')
    plt.plot(list(zip(*log))[1], label='Reward thresholds')
    plt.legend()
    plt.grid()

    plt.subplot(1, 2, 2)
    plt.hist(rewards_batch, bins=50)
    plt.vlines([log[-1][1]],
               [0], [100], label="percentile", color='red')
    plt.legend()
    plt.grid()

    plt.show()
    print("mean reward = %.3f, threshold=%.3f" % (log[-1][0], log[-1][1]))

def select_elites(states_batch, actions_batch, rewards_batch, percentile=50):
    """
    Select states and actions from games that have rewards >= percentile
    :param states_batch: list of lists of states, states_batch[session_i][t]
    :param actions_batch: list of lists of actions, actions_batch[session_i][t]
    :param rewards_batch: list of rewards, rewards_batch[session_i][t]

    :returns: elite_states,elite_actions, both 1D lists of states and respective actions from elite sessions

    Please return elite states and actions in their original order 
    [i.e. sorted by session number and timestep within session]

    If you're confused, see examples below. Please don't assume that states are integers (they'll get different later).
    """

    reward_threshold = np.percentile(rewards_batch, percentile)
    elite_idx = np.where(np.array(rewards_batch) >= reward_threshold)[0]
    elite_states = [state for idx in elite_idx for state in states_batch[idx]]
    elite_actions = [action for idx in elite_idx for action in actions_batch[idx]]
    return elite_states, elite_actions, reward_threshold

def generate_session_11(env, policy, t_max=10000):
    """
    Play game until end or for t_max ticks.
    :param policy: an array of shape [n_states,n_actions] with action probabilities
    :returns: list of states, list of actions and sum of rewards
    """
    states, actions = [], []
    total_reward = 0.
    s = env.reset()

    for t in range(t_max):
        a = np.random.choice(policy.shape[1], p=policy[s])

        new_s, r, done, info = env.step(a)

        states.append(s)
        actions.append(a)
        total_reward += r

        s = new_s
        if done:
            break
    return states, actions, total_reward


def generate_sessions_11(n_sessions, policy, t_max=10000):
    env = gym.make("Taxi-v2")
    return [generate_session_11(env, policy, t_max) for _ in range(n_sessions)]


def run_task_11(percentile, n_samples, n_jobs=2):
    env=gym.make("Taxi-v2")
    n_states = env.observation_space.n
    n_actions = env.action_space.n
    
    policy = np.ones([n_states, n_actions])/n_actions

    learning_rate = 0.5  # add this thing to all counts for stability

    log = []
    start = time()
    with Pool(n_jobs) as p:
        for i in tqdm(range(200)):
        
            n_sessions = [n_samples // n_jobs] * n_jobs
            n_sessions[-1] = n_samples - (n_jobs - 1) * n_samples // n_jobs
        
        
            sessions = chain(*p.map(partial(generate_sessions_11, policy=policy), n_sessions))
        
            states_batch, actions_batch, rewards_batch = zip(*sessions)

            elite_states, elite_actions, threshold = select_elites(states_batch, actions_batch, rewards_batch, percentile)

            new_policy = update_policy(elite_states, elite_actions)

            policy = learning_rate * new_policy + (1 - learning_rate) * policy
            
            log.append([np.mean(rewards_batch), threshold])

        # display results on chart
    show_progress(rewards_batch, log)
    print('elapsed {:d}ms'.format(int(1000*(time() - start + 0.5))))

# %%
run_task_11(percentile=10, n_samples=125, n_jobs=10)
# Out:
# mean reward = -195.008, threshold=-227.000
# elapsed 27001ms

# %%
run_task_11(percentile=50, n_samples=125, n_jobs=10)
# Out:
# mean reward = -198.372, threshold=-5.000
# elapsed 13243ms

# %%
run_task_11(percentile=90, n_samples=125, n_jobs=10)
# Out:
# mean reward = -654.322, threshold=-11.000
# elapsed 22177ms

# %%
run_task_11(percentile=10, n_samples=250, n_jobs=10)
# Out:
# mean reward = -67.860, threshold=-200.000
# elapsed 34321ms

# %%
run_task_11(percentile=50, n_samples=250, n_jobs=10)
# Out:
# mean reward = -120.464, threshold=5.000
# elapsed 13494ms

# %%
run_task_11(percentile=90, n_samples=250, n_jobs=10)
# Out:
# mean reward = -544.072, threshold=10.000
# elapsed 37926ms

# %%
run_task_11(percentile=10, n_samples=500, n_jobs=10)
# Out:
# mean reward = -47.394, threshold=-200.000
# elapsed 56037ms

# %%
run_task_11(percentile=50, n_samples=500, n_jobs=10)
# Out:
# mean reward = -39.748, threshold=8.000
# elapsed 19709ms

# %%
run_task_11(percentile=90, n_samples=500, n_jobs=10)
# Out:
# mean reward = -491.134, threshold=11.000
# elapsed 59173ms

# %% [markdown]
# ---
#
# **1**
#
# При увеличении `n_samples`:
#
# 1. Обучение становится более стабильным (если смотреть на разброс значений наград)
# 2. Результат становится лучше
#
# Следовательно, нужно генерировать больше сэмплов. Связано это с тем, что в выборку попадают разнообразные траектории, которые могут затрагивать в том числе и редкие кейсы.
#
# `percentile`:
#
# При уменьшении порога обучение становится очень медленным (особенно в начале), так как попадает много "шумных" траекторий, которые не несут в себе "полезных" действий. При его увеличении обучение становится быстрым, но алгоритм быстро сходится к "локальному минимому", где в модели нет варианта действий для многих нетипичных событий, так они просто не попадают в батч для обучения.
#
# ---
#
# **2**
#
# Пользуясь накопленной информацией, сделаем следующее:
#
# 1. возьмем `n_samples` по-больше
# 2. в начале обучения поставим `percentile` большим, чтобы отсеять "совсем плохие" траектории, а затем будем уменьшать. Это аналогично уменьшению шага обучения

# %%
def run_task_12(n_samples, n_jobs=2):
    env=gym.make("Taxi-v2")
    n_states = env.observation_space.n
    n_actions = env.action_space.n
    
    policy = np.ones([n_states, n_actions])/n_actions

    learning_rate = 0.5  # add this thing to all counts for stability

    log = []
    start = time()
    with Pool(n_jobs) as p:
        for i in tqdm(range(200)):
            
            if i < 30:
                percentile = 70
            elif i < 80:
                percentile = 20
            elif i < 120:
                percentile = 10
            else:
                percentile = 5
        
            n_sessions = [n_samples // n_jobs] * n_jobs
            n_sessions[-1] = n_samples - (n_jobs - 1) * n_samples // n_jobs
        
        
            sessions = chain(*p.map(partial(generate_sessions_11, policy=policy), n_sessions))
        
            states_batch, actions_batch, rewards_batch = zip(*sessions)

            elite_states, elite_actions, threshold = select_elites(states_batch, actions_batch, rewards_batch, percentile)

            new_policy = update_policy(elite_states, elite_actions)

            policy = learning_rate * new_policy + (1 - learning_rate) * policy
            
            log.append([np.mean(rewards_batch), threshold])

        # display results on chart
    show_progress(rewards_batch, log)
    print('elapsed {:d}ms'.format(int(1000*(time() - start + 0.5))))

# %%
run_task_12(n_samples=500, n_jobs=10)
# Out:
# mean reward = 7.516, threshold=2.000
# elapsed 14076ms

# %% [markdown]
# # Homework part II
#
# ### Deep crossentropy method
#
# By this moment you should have got enough score on [CartPole-v0](https://gym.openai.com/envs/CartPole-v0) to consider it solved (see the link). It's time to try something harder.
#
# * if you have any trouble with CartPole-v0 and feel stuck, feel free to ask us or your peers for help.
#
# ### Tasks
#
# * __2.1__ (3 pts) Pick one of environments: MountainCar-v0 or LunarLander-v2.
#   * For MountainCar, get average reward of __at least -150__
#   * For LunarLander, get average reward of __at least +50__
#
# See the tips section below, it's kinda important.
# __Note:__ If your agent is below the target score, you'll still get most of the points depending on the result, so don't be afraid to submit it.
#
#   __2.2__ (bonus: 4++ pt) Devise a way to speed up training at least 2x against the default version
# Obvious improvement: use joblib
# Try re-using samples from 3-5 last iterations when computing threshold and training
# Experiment with amount of training iterations and learning rate of the neural network (see params)
# Please list what you did in anytask submission form

# %%
# if you see "<classname> has no attribute .env", remove .env or update gym
env = gym.make("LunarLander-v2").env
env.reset()
n_actions = env.action_space.n
plt.imshow(env.render("rgb_array"))

# %%
env.action_space.n
# Out:
# 4

# %%
env.reset()
# Out:
# array([ 0.00777559,  1.4222226 ,  0.7875618 ,  0.50231546, -0.00900313,
#        -0.17839462,  0.        ,  0.        ], dtype=float32)

# %%
from multiprocessing import Pool
from itertools import chain
from time import time
from tqdm import tqdm_notebook as tqdm
from functools import partial

def select_elites_lunar(states_batch, actions_batch, rewards_batch, percentile=50):
    """
    Select states and actions from games that have rewards >= percentile
    :param states_batch: list of lists of states, states_batch[session_i][t]
    :param actions_batch: list of lists of actions, actions_batch[session_i][t]
    :param rewards_batch: list of rewards, rewards_batch[session_i][t]

    :returns: elite_states,elite_actions, both 1D lists of states and respective actions from elite sessions

    Please return elite states and actions in their original order 
    [i.e. sorted by session number and timestep within session]

    If you're confused, see examples below. Please don't assume that states are integers (they'll get different later).
    """

    reward_threshold = np.percentile(rewards_batch, percentile)
    elite_idx = np.where(np.array(rewards_batch) >= reward_threshold)[0]
    elite_states = [state for idx in elite_idx for state in states_batch[idx]]
    elite_actions = [action for idx in elite_idx for action in actions_batch[idx]]
#     print('kek')
    return elite_states, elite_actions, reward_threshold


def show_progress(rewards_batch, log, reward_range=[-990, +10], ax=None):
    """
    A convenience function that displays training progress. 
    No cool math here, just charts.
    """

    clear_output(True)
    plt.figure(figsize=[8, 4])
    plt.subplot(1, 2, 1)
    plt.plot(list(zip(*log))[0], label='Mean rewards')
    plt.plot(list(zip(*log))[1], label='Reward thresholds')
    plt.legend()
    plt.grid()

    plt.subplot(1, 2, 2)
    plt.hist(rewards_batch, range=(-300, 300), bins=50)
    plt.vlines([log[-1][1]],
               [0], [100], label="percentile", color='red')
    plt.legend()
    plt.grid()

    plt.show()
    print("mean reward = %.3f, threshold=%.3f" % (log[-1][0], log[-1][1]))


def select_elites_list(states_batch, actions_batch, rewards_batch, percentile=50):
    """
    Select states and actions from games that have rewards >= percentile
    :param states_batch: list of lists of states, states_batch[session_i][t]
    :param actions_batch: list of lists of actions, actions_batch[session_i][t]
    :param rewards_batch: list of rewards, rewards_batch[session_i][t]

    :returns: elite_states,elite_actions, both 1D lists of states and respective actions from elite sessions

    Please return elite states and actions in their original order 
    [i.e. sorted by session number and timestep within session]

    If you're confused, see examples below. Please don't assume that states are integers (they'll get different later).
    """

    reward_threshold = np.percentile(rewards_batch, percentile)
    elite_idx = np.where(np.array(rewards_batch) >= reward_threshold)[0]
    elite_states = [states_batch[idx] for idx in elite_idx]
    elite_actions = [actions_batch[idx] for idx in elite_idx]
    elite_rewards = [rewards_batch[idx] for idx in elite_idx]
#     print('kek')
    return elite_states, elite_actions, elite_rewards, reward_threshold


def select_elite_idx(rewards_batch, percentile):
    reward_threshold = np.percentile(rewards_batch, percentile)
    elite_idx = np.where(np.array(rewards_batch) >= reward_threshold)[0]
    return elite_idx, reward_threshold

def generate_session_21(env, agent, t_max=10000):
    """
    Play game until end or for t_max ticks.
    :param policy: an array of shape [n_states,n_actions] with action probabilities
    :returns: list of states, list of actions and sum of rewards
    """
    states, actions = [], []
    total_reward = 0.
    s = env.reset()
    for t in range(t_max):

        # predict array of action probabilities
        probs = agent.predict_proba([s])[0]

        a = np.random.choice(n_actions, p=probs)

        new_s, r, done, info = env.step(a)

        # record sessions like you did before
        states.append(s)
        actions.append(a)
        total_reward += r

        s = new_s
        if done:
            break
    return states, actions, total_reward


def generate_sessions_21(n_sessions, agent, t_max=400, env_name="LunarLander-v2"):
    env = gym.make(env_name).env
    return [generate_session_21(env, agent, t_max) for _ in range(n_sessions)]

# %%
from sklearn.neural_network import MLPClassifier
agent = MLPClassifier(hidden_layer_sizes=(100,), 
                      activation='tanh',
                      learning_rate_init=0.005,
                      warm_start=True,
                      max_iter=1,
                      validation_fraction=0,
                      batch_size=200,
                      n_iter_no_change=10000,
                      )

from collections import deque
from itertools import chain
from IPython.display import clear_output
class queue():
    def __init__(self, max_size):
        self._max_size=max_size
        self._current_size = 0
        self._elite_actions = deque()
        self._elite_states = deque()
        self._rewards_batch = deque()
        
    def get(self):
        return list(chain(*self._elite_actions)), list(chain(*self._elite_states)), list(chain(*self._rewards_batch))
#         return list(self._elite_actions), list(self._elite_states), list(self._rewards_batch)
    
    def push(self, elite_actions, elite_states, reward_batch):
        while self._current_size >= self._max_size:
           
            self._elite_actions.popleft()
            self._elite_states.popleft()
            self._rewards_batch.popleft()
            self._current_size -= 1
        self._elite_actions.append(elite_actions)
        self._elite_states.append(elite_states)
        self._rewards_batch.append(reward_batch)
        self._current_size += 1


def run_task_12(n_jobs=12, env_name="LunarLander-v2", t_max=400):
    
    env=gym.make(env_name)
    n_actions = env.action_space.n
    
    
    # initialize agent to the dimension of state an amount of actions
    agent.fit([env.reset()]*n_actions, range(n_actions))

    log = []
    start = time()
    
    q = queue(1)
    
    
    
    with Pool(n_jobs) as p:
        for i in tqdm(range(500)):
            
            if i < 100:
                percentile = 80
                n_samples = 100
                q._max_size = 6
            elif i < 170:
                percentile = 55
                q._max_size = 6
            elif i < 350:
                percentile = 90
                q._max_size = 6
            elif i < 450:
                percentile = 7
                q._max_size = 6
            else:
                percentile = 80
        
            n_sessions = [n_samples // n_jobs] * n_jobs
            n_sessions[-1] = n_samples - (n_jobs - 1) * n_samples // n_jobs
        
            sessions = chain(*p.map(partial(generate_sessions_21, agent=agent, env_name=env_name, t_max=t_max), n_sessions))
        
            states_batch, actions_batch, rewards_batch = zip(*sessions)
            

            q.push(actions_batch, states_batch, rewards_batch)
            actions_batch, states_batch, rewards_batch = q.get()
            
            elite_states, elite_actions, threshold = select_elites_lunar(states_batch, actions_batch, rewards_batch, percentile)

            agent.fit(elite_states, elite_actions)
            
            log.append([np.mean(rewards_batch), threshold])
            
            print(np.mean(rewards_batch), end='\r')

            # display results on chart
            show_progress(rewards_batch, log)
    print('elapsed {:d}ms'.format(int(1000*(time() - start + 0.5))))

# %%
run_task_12(n_jobs=12)
# Out:
# mean reward = 267.974, threshold=300.513
# elapsed 848395ms

# %%
import pickle
with open('mlp_lunar_lander_v2.pkl', 'wb') as f:
    pickle.dump(agent, f)

# %%
# record sessions
import gym.wrappers
env = gym.wrappers.Monitor(gym.make("LunarLander-v2"),
                           directory="videos", force=True)
sessions = [generate_session_21(env, agent, 500) for _ in range(1)]
env.close()

# %%
# show video
from IPython.display import HTML
import os

video_names = list(
    filter(lambda s: s.endswith(".mp4"), os.listdir("./videos/")))

HTML("""
<video width="640" height="480" controls>
  <source src="{}" type="video/mp4">
</video>
""".format("./videos/"+video_names[-1]))  # this may or may not be _last_ video. Try other indices
# Out:
# <video width="640" height="480" controls>
#   <source src="./videos/openaigym.video.34.10651.video000000.mp4" type="video/mp4">
# </video>

# %% [markdown]
# ## Что было сделано
#
#
# 1. __сильно ускорило обучение__ Максимальное время симуляции было поставлено 400 тиков симуляции -- равноценно 10 секундам видео.
# 2. Взята однослойная сетка со 100 нейронами. Оказалось, что она работает намного лучше, чем, например, вариант двуслойной сети. Также tanh в качестве активации оказался много лучше relu. По оптимизатору не удалось сделать существенных улучшений, кроме как уменьшение шага обучения.
# 3. __сильно повлияло на результат__ Было замечено, что иногда распределение становится с двумя горбами, причем "левый" горб со временем становился все больше. Наверное, это соответствовало случаям, которые не учитывались в начальном обучении. Чтобы это решить, время от времени порог по перцентилям понижался, чтобы захватывать правый хвост "плохого распределения", затем, после "воссоединения" горбов, порог возвращался.
# 4. __сильно ускорило обучение__ Генерация семплов была распараллелена. Причем внутри каждого процесса создавался свое окружение, на котором уже гонялось k семплов -- оказался самый эффективный вариант (создание окружения ведь тоже занимало время).
# 5. __сильно ускорило обучение__ Использовалась очередь из последних 6 сгенерированных семплов. Элитные действия и состояния уже выбирались из объединенной выборки. Это позволило не тратить много времени на генерацию, так как это было основным боттленеком.
# 6. Исследовалось влияние количества эпох обучения сетки на элитных семплах на результат. Оказалось, что лучше всего работает с одной эпохой -- это можно объяснить тем, что использовалась очередь из последних семплов, поэтому каждый из них участвовал в обучении от 0 до k раз (в зависимости, попал он в элитные или нет).

# %% [markdown]
# ## результаты и выводы

# %% [markdown]
# 1. Удалось обучить агента так, что его средняя награда > 250
# 2. Тем не менее, на распределении наград видно, что все еще немало случаев, где получаемая награда не максимальна. Анализ видео показал, что это связано с прилунениями на край зоны с влажками. Так как время от времени там идет наклон вниз, агент не может оттуда выбраться, как бы он не старался, и, как следствие, он там застревает и просто попусту тратит энергию. Обучить его оттуда выбираться кажется сложной задачей -- ведь для этого нужно понять, что надо слегка подлететь, а потом снова прилуниться.

# %% [markdown]
#
# ### Tips
# * Gym page: [mountaincar](https://gym.openai.com/envs/MountainCar-v0), [lunarlander](https://gym.openai.com/envs/LunarLander-v2)
# * Sessions for MountainCar may last for 10k+ ticks. Make sure ```t_max``` param is at least 10k.
#  * Also it may be a good idea to cut rewards via ">" and not ">=". If 90% of your sessions get reward of -10k and 20% are better, than if you use percentile 20% as threshold, R >= threshold __fails cut off bad sessions__ whule R > threshold works alright.
# * _issue with gym_: Some versions of gym limit game time by 200 ticks. This will prevent cem training in most cases. Make sure your agent is able to play for the specified __t_max__, and if it isn't, try `env = gym.make("MountainCar-v0").env` or otherwise get rid of TimeLimit wrapper.
# * If you use old _swig_ lib for LunarLander-v2, you may get an error. See this [issue](https://github.com/openai/gym/issues/100) for solution.
# * If it won't train it's a good idea to plot reward distribution and record sessions: they may give you some clue. If they don't, call course staff :)
# * 20-neuron network is probably not enough, feel free to experiment.
#
# ### Bonus tasks
#
# * __2.3 bonus__ Try to find a network architecture and training params that solve __both__ environments above (_Points depend on implementation. If you attempted this task, please mention it in anytask submission._)
#
# * __2.4 bonus__ Solve continuous action space task with `MLPRegressor` or similar.
#   * Start with ["Pendulum-v0"](https://github.com/openai/gym/wiki/Pendulum-v0).
#   * Since your agent only predicts the "expected" action, you will have to add noise to ensure exploration.
#   * [MountainCarContinuous-v0](https://gym.openai.com/envs/MountainCarContinuous-v0), [LunarLanderContinuous-v2](https://gym.openai.com/envs/LunarLanderContinuous-v2)
#   * 4 points for solving. Slightly less for getting some results below solution threshold. Note that discrete and continuous environments may have slightly different rules aside from action spaces.
#
#
# If you're still feeling unchallenged, consider the project (see other notebook in this folder).

# %% [markdown]
# # 2.3

# %%
env = gym.make("MountainCar-v0").env
env.reset()
n_actions = env.action_space.n
plt.imshow(env.render("rgb_array"))

# %%
# the same network as for lunar lander v2
agent = MLPClassifier(hidden_layer_sizes=(100,), 
                      activation='tanh',
                      learning_rate_init=0.005,
                      warm_start=True,
                      max_iter=1,
                      validation_fraction=0,
                      batch_size=200,
                      n_iter_no_change=10000,
                      )
# the only difference here is t_max (=400 for lunar lander).
run_task_12(n_jobs=12, env_name="MountainCar-v0", t_max=20000)
# Out:
# mean reward = -131.007, threshold=-107.000
# elapsed 408281ms

# %%
import pickle
with open('mlp_mountian_car_v0.pkl', 'wb') as f:
    pickle.dump(agent, f)

# %%
# record sessions
import gym.wrappers
env = gym.wrappers.Monitor(gym.make("MountainCar-v0"),
                           directory="videos", force=True)
sessions = [generate_session_21(env, agent, 10000) for _ in range(1)]
env.close()

# %%
# show video
from IPython.display import HTML
import os

video_names = list(
    filter(lambda s: s.endswith(".mp4"), os.listdir("./videos/")))

HTML("""
<video width="640" height="480" controls>
  <source src="{}" type="video/mp4">
</video>
""".format("./videos/"+video_names[-1]))  # this may or may not be _last_ video. Try other indices
# Out:
# <video width="640" height="480" controls>
#   <source src="./videos/openaigym.video.41.10651.video000000.mp4" type="video/mp4">
# </video>

# %% [markdown]
# ## Что было сделано
#
# 1. изменен t_max с 400 до 20000
#
# ## Результаты и выводы
#
# 1. Удалось обучить агента получать среднюю награду ~ -130
# 2. Агент получился не идеальным. Захардокженный в первом ноутбуке агент получал награду в среднем от -125, тогда как текущий получает примерно от -200. Обычно это из-за того, что иногда он долго "раскачивается".

# %% [markdown]
# # 2.4

# %%
env = gym.make("Pendulum-v0").env
env.reset()
plt.imshow(env.render("rgb_array"))

# %%
env.action_space
# Out:
# Box(1,)

# %%
env.reset()
# Out:
# array([-0.96048854, -0.27831955,  0.38617098])

# %%
np.random.binomial(1, 1)
# Out:
# 1

# %%
-2 + 4 / (1 + np.exp(-2))
# Out:
# 1.5231883119115293

# %%
k = (2 + 1.5231883119115293) / 4

-np.log(1/k-1)
# Out:
# 1.9999999999999991

# %%
from multiprocessing import Pool
from itertools import chain
from time import time
from tqdm import tqdm_notebook as tqdm
from functools import partial

def select_elites(states_batch, actions_batch, rewards_batch, percentile=50):
    """
    Select states and actions from games that have rewards >= percentile
    :param states_batch: list of lists of states, states_batch[session_i][t]
    :param actions_batch: list of lists of actions, actions_batch[session_i][t]
    :param rewards_batch: list of rewards, rewards_batch[session_i][t]

    :returns: elite_states,elite_actions, both 1D lists of states and respective actions from elite sessions

    Please return elite states and actions in their original order 
    [i.e. sorted by session number and timestep within session]

    If you're confused, see examples below. Please don't assume that states are integers (they'll get different later).
    """

    reward_threshold = np.percentile(rewards_batch, percentile)
    elite_idx = np.where(np.array(rewards_batch) >= reward_threshold)[0]
    elite_states = [state for idx in elite_idx for state in states_batch[idx]]
    elite_actions = [action for idx in elite_idx for action in actions_batch[idx]]
#     print('kek')
    return elite_states, elite_actions, reward_threshold


def show_progress(rewards_batch, log, reward_range=[-1000, +1000], ax=None):
    """
    A convenience function that displays training progress. 
    No cool math here, just charts.
    """

    clear_output(True)
    plt.figure(figsize=[8, 4])
    plt.subplot(1, 2, 1)
    plt.plot(list(zip(*log))[0], label='Mean rewards')
    plt.plot(list(zip(*log))[1], label='Reward thresholds')
    plt.legend()
    plt.grid()

    plt.subplot(1, 2, 2)
    plt.hist(rewards_batch, bins=50)
    plt.vlines([log[-1][1]],
               [0], [100], label="percentile", color='red')
    plt.legend()
    plt.grid()

    plt.show()
    print("mean reward = %.3f, threshold=%.3f" % (log[-1][0], log[-1][1]))


def generate_session_24(env, agent, t_max=10000, p=0.03):
    """
    Play game until end or for t_max ticks.
    :param policy: an array of shape [n_states,n_actions] with action probabilities
    :returns: list of states, list of actions and sum of rewards
    """
    states, actions = [], []
    total_reward = 0.
    s = env.reset()
    ms, MS = 100, 0
    for t in range(t_max):
        mu, sigma = agent.predict([s])[0]
        
        
        sigma = np.exp(sigma)/2
        mu = 2 * mu

        sample =  np.random.normal(loc=mu, scale=sigma)
        
        action = [min(1.99, max(-1.99, sample))]
        
        mu = action[0] / 2
        sigma = np.log(sigma*2)

        new_s, r, done, info = env.step(action)

        # record sessions like you did before
        states.append(s)
        
        actions.append(mu)
        total_reward += r

        s = new_s
        if done:
            break
#     print(ms, MS)

    return states, actions, total_reward


def generate_sessions_24(n_sessions, agent, t_max=400, env_name="Pendulum-v0",p=0.1):
    env = gym.make(env_name).env
    return [generate_session_24(env, agent, t_max,p) for _ in range(n_sessions)]

# %%
from collections import deque
from itertools import chain
from IPython.display import clear_output
class queue():
    def __init__(self, max_size):
        self._max_size=max_size
        self._current_size = 0
        self._elite_actions = deque()
        self._elite_states = deque()
        self._rewards_batch = deque()
        
    def get(self):
        return list(chain(*self._elite_actions)), list(chain(*self._elite_states)), list(chain(*self._rewards_batch))
#         return list(self._elite_actions), list(self._elite_states), list(self._rewards_batch)
    
    def push(self, elite_actions, elite_states, reward_batch):
        while self._current_size >= self._max_size:
           
            self._elite_actions.popleft()
            self._elite_states.popleft()
            self._rewards_batch.popleft()
            self._current_size -= 1
        self._elite_actions.append(elite_actions)
        self._elite_states.append(elite_states)
        self._rewards_batch.append(reward_batch)
        self._current_size += 1
        
def show_progress(v, log, elite_actions, reward_range=[-990, +10], ax=None):
    """
    A convenience function that displays training progress. 
    No cool math here, just charts.
    """

    clear_output(True)
    plt.figure(figsize=[16, 4])
    plt.subplot(1, 4, 1)
    plt.plot(list(zip(*log))[0], label='Mean rewards')
    plt.plot(list(zip(*log))[1], label='Reward thresholds')
    plt.legend()
    plt.grid()

    plt.subplot(1, 4, 2)
    plt.hist(v, bins=50)
    plt.title('rewards')
    
    plt.subplot(1, 4, 3)
    plt.hist([e for e in elite_actions], bins=50, range=(-2, 2))
    plt.title('loc')

    
#     plt.vlines([log[-1][1]],
#                [0], [100], label="percentile", color='red')
    plt.legend()
    plt.grid()

    plt.show()
    print("mean reward = %.3f, threshold=%.3f" % (log[-1][0], log[-1][1]))

from sklearn.neural_network import MLPRegressor
agent = MLPRegressor(hidden_layer_sizes=(30,30), 
                      activation='tanh',
                      learning_rate_init=0.005,
                      n_iter_no_change=100000,
                      warm_start=True,
                      alpha=0.0001,
                      max_iter=1,
                      validation_fraction=0,
                      batch_size=20000,
                      )

def run_task_24(n_jobs=12, env_name="Pendulum-v0", t_max=400):

    log = []
    start = time()
    
    q = queue(1)
    X, Y = [env.reset() for i in range(2000)], [[-10 + 20*np.random.random(), 0] for i in range(2000)]
    agent.fit(X, Y)
    p=0
    k=1.1
    with Pool(n_jobs) as pool:
        for i in tqdm(range(500)):
            
            if i < 1000:
                
                percentile = 90
                n_samples = 800
                q._max_size = 1
            elif i < 150:
                percentile = 99
                q._max_size = 6
            elif i < 60:
                percentile = 50
                q._max_size = 6
            elif i < 450:
                percentile = 80
                q._max_size = 6
            else:
                percentile = 80
                
            
            if p > 0.5:
                k = 0.9
            if p < 0.01:
                k = 1.05
            p = p * k
            n_sessions = [n_samples // n_jobs] * n_jobs
            n_sessions[-1] = n_samples - (n_jobs - 1) * n_samples // n_jobs
        
            sessions = chain(*pool.map(partial(generate_sessions_24, agent=agent, env_name=env_name, t_max=t_max, p=p), n_sessions))
        
            states_batch, actions_batch, rewards_batch = zip(*sessions)
            

            q.push(actions_batch, states_batch, rewards_batch)
            actions_batch, states_batch, rewards_batch = q.get()
            
            elite_states, elite_actions, threshold = select_elites(states_batch, actions_batch, rewards_batch, percentile)
            agent.fit(elite_states, elite_actions)
            
            log.append([np.mean(rewards_batch), threshold])
            
            print(np.mean(rewards_batch), end='\r')

            # display results on chart
            show_progress(rewards_batch, log, elite_actions)
            print(p)
    print('elapsed {:d}ms'.format(int(1000*(time() - start + 0.5))))

# %%
run_task_24(env_name="Pendulum-v0", n_jobs=12, t_max=300)
# Out:
# No handles with labels found to put in legend.
# Process ForkPoolWorker-113:
# Process ForkPoolWorker-116:
# Traceback (most recent call last):
# Process ForkPoolWorker-115:
# Process ForkPoolWorker-120:
# Process ForkPoolWorker-118:
# Process ForkPoolWorker-119:
# Process ForkPoolWorker-110:
# Process ForkPoolWorker-114:
# Process ForkPoolWorker-111:
# Process ForkPoolWorker-109:
# Process ForkPoolWorker-112:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-117:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# ...

# %%
# !rm -rf ./videos/*

# %%
# record sessions
import gym.wrappers
env = gym.wrappers.Monitor(gym.make("Pendulum-v0"),
                           directory="videos", force=True)
sessions = [generate_session_24(env, agent,300, 0) for _ in range(1)]
env.close()

# %%
# show video
from IPython.display import HTML
import os

video_names = list(
    filter(lambda s: s.endswith(".mp4"), os.listdir("./videos/")))

HTML("""
<video width="640" height="480" controls>
  <source src="{}" type="video/mp4">
</video>
""".format("./videos/"+video_names[-1]))  # this may or may not be _last_ video. Try other indices
# Out:
# <video width="640" height="480" controls>
#   <source src="./videos/openaigym.video.0.8051.video000000.mp4" type="video/mp4">
# </video>
